# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Documents\\fundamentals.csv'

# %%
import pandas as pd
fundamentals = pd.read_csv('fundamentals.csv')
print(fundamentals.head())
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
rows_selected = fundamentals['Ticker Symbol'].iloc[400:410]
print(rows_selected)
# Out:
# 400    CTAS
# 401    CTAS
# 402    CTAS
# 403    CTAS
# 404     CTL
# 405     CTL
# 406     CTL
# 407     CTL
# 408    CTSH
# 409    CTSH
# Name: Ticker Symbol, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.histplot(rows_selected)
plt.title('Frequency of ticker symbols')
# Out:
# Text(0.5, 1.0, 'Frequency of ticker symbols')

# %%
print(fundamentals.sample(15))
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 1557        1557           TSO    2015-12-31      1.568000e+09
# 1736        1736           XEL    2015-12-31      1.728410e+09
# 1741        1741          XLNX    2013-03-30      3.334300e+08
# 329          329           CLX    2016-06-30      1.035000e+09
# 1391        1391          SCHW    2013-12-31      3.838600e+10
# 667          667           FMC    2015-12-31      1.273500e+09
# 1379        1379           RSG    2014-12-31      1.345000e+09
# 1389        1389           SCG    2015-12-31      9.910000e+08
# 545          545           EMN    2013-12-31      1.470000e+09
# 1235        1235          PCAR    2015-12-31      3.569000e+08
# 1017        1017           MAC    2014-12-31      1.003118e+09
# 613          613          FAST    2014-12-31      2.853530e+08
# 855          855           IRM    2012-12-31      5.949330e+08
# 108          108          AMGN    2013-12-31      5.442000e+09
# ...

# %%
print(fundamentals.head(15))
# Out:
#     Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0            0           AAL    2012-12-31      3.068000e+09
# 1            1           AAL    2013-12-31      4.975000e+09
# 2            2           AAL    2014-12-31      4.668000e+09
# 3            3           AAL    2015-12-31      5.102000e+09
# 4            4           AAP    2012-12-29      2.409453e+09
# 5            5           AAP    2013-12-28      2.609239e+09
# 6            6           AAP    2015-01-03      3.616038e+09
# 7            7           AAP    2016-01-02      3.757085e+09
# 8            8          AAPL    2013-09-28      3.622300e+10
# 9            9          AAPL    2014-09-27      4.864900e+10
# 10          10          AAPL    2015-09-26      6.067100e+10
# 11          11          AAPL    2016-09-24      5.932100e+10
# 12          12          ABBV    2012-12-31      5.734000e+09
# 13          13          ABBV    2013-12-31      6.448000e+09
# ...

# %%
#select complete rows
complete_rows = fundamentals.iloc[400:410]
print(complete_rows)
print(type(complete_rows))
# Out:
#      Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 400         400          CTAS    2013-05-31      5.480690e+08
# 401         401          CTAS    2014-05-31      6.296280e+08
# 402         402          CTAS    2015-05-31      5.079650e+08
# 403         403          CTAS    2016-05-31      5.655550e+08
# 404         404           CTL    2012-12-31      3.156000e+09
# 405         405           CTL    2013-12-31      3.110000e+09
# 406         406           CTL    2014-12-31      3.158000e+09
# 407         407           CTL    2015-12-31      2.881000e+09
# 408         408          CTSH    2012-12-31      1.227634e+09
# 409         409          CTSH    2013-12-31      1.591615e+09
#
#      Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 400          -42704000.0                    409000.0           14.0
# 401          -56231000.0                    229000.0           17.0
# 402           -1443000.0                    339000.0           22.0
# ...

# %%
complete_rows.isnull().sum()
# Out:
# Unnamed: 0                      0
# Ticker Symbol                   0
# Period Ending                   0
# Accounts Payable                0
# Accounts Receivable             0
#                                ..
# Total Revenue                   0
# Treasury Stock                  0
# For Year                        0
# Earnings Per Share              0
# Estimated Shares Outstanding    0
# Length: 79, dtype: int64

# %%
complete_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 400 to 409
# Data columns (total 79 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           10 non-null     int64
#  1   Ticker Symbol                                        10 non-null     object
#  2   Period Ending                                        10 non-null     object
#  3   Accounts Payable                                     10 non-null     float64
#  4   Accounts Receivable                                  10 non-null     float64
#  5   Add'l income/expense items                           10 non-null     float64
#  6   After Tax ROE                                        10 non-null     float64
#  7   Capital Expenditures                                 10 non-null     float64
# ...

# %%
complete_rows.loc[:, 'Period Ending'] = pd.to_datetime(complete_rows.loc[:,'Period Ending'], format = '%Y-%m-%d') 
complete_rows.loc[:, 'For Year'] = pd.to_datetime(complete_rows.loc[:, 'For Year'], format = '%Y-%m-%d')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
print(complete_rows.dtypes)
# Out:
# Unnamed: 0                               int64
# Ticker Symbol                           object
# Period Ending                   datetime64[ns]
# Accounts Payable                       float64
# Accounts Receivable                    float64
#                                      ...
# Total Revenue                          float64
# Treasury Stock                         float64
# For Year                        datetime64[ns]
# Earnings Per Share                     float64
# Estimated Shares Outstanding           float64
# Length: 79, dtype: object

# %%
print(complete_rows.corr())
# Out:
#                               Unnamed: 0  Accounts Payable  \
# Unnamed: 0                      1.000000          0.505914
# Accounts Payable                0.505914          1.000000
# Accounts Receivable            -0.826045         -0.670221
# Add'l income/expense items      0.209337         -0.142837
# After Tax ROE                  -0.150645         -0.816828
# ...                                  ...               ...
# Total Liabilities & Equity      0.311231          0.971720
# Total Revenue                   0.472824          0.995712
# Treasury Stock                  0.738890          0.802071
# Earnings Per Share             -0.100665         -0.778753
# Estimated Shares Outstanding    0.528528          0.994154
#
#                               Accounts Receivable  Add'l income/expense items  \
# Unnamed: 0                              -0.826045                    0.209337
# Accounts Payable                        -0.670221                   -0.142837
# ...

# %%
plt.figure(figsize = (18,100))
sns.heatmap(complete_rows.corr())
# Out:
# <AxesSubplot:>

# %%
a = sns.scatterplot(data = complete_rows, x = 'Period Ending', y = 'Earnings Per Share',
                hue = 'Ticker Symbol')
a.set_title ('Earnings per share per year')
# Out:
# Text(0.5, 1.0, 'Earnings per share per year')

# %%
sns.scatterplot(data = complete_rows, x = 'Total Equity', y = 'Total Assets', 
                  hue = 'Ticker Symbol', size = 'Total Current Assets')
# Out:
# <AxesSubplot:xlabel='Total Equity', ylabel='Total Assets'>

# %%
sns.scatterplot(data = complete_rows, x = 'Total Equity', y = 'Total Liabilities', 
                  hue = 'Ticker Symbol', size = 'Total Current Liabilities')
# Out:
# <AxesSubplot:xlabel='Total Equity', ylabel='Total Liabilities'>

# %%
sns.scatterplot(data = complete_rows, x = 'Total Revenue', y = 'Total Assets', 
                  hue = 'Ticker Symbol', size = 'Total Liabilities')
# Out:
# <AxesSubplot:xlabel='Total Revenue', ylabel='Total Assets'>

# %%
sns.scatterplot(data = complete_rows, y = 'Gross Profit', x = 'Net Income', 
                  hue = 'Ticker Symbol', size = 'Earnings Per Share')
# Out:
# <AxesSubplot:xlabel='Net Income', ylabel='Gross Profit'>

# %%
sns.scatterplot(data = complete_rows, y = 'Operating Margin', x = 'Profit Margin', 
                  hue = 'Ticker Symbol', size = 'Earnings Per Share')
# Out:
# <AxesSubplot:xlabel='Profit Margin', ylabel='Operating Margin'>

# %%
sns.scatterplot(data = complete_rows, y = 'Earnings Per Share', x = 'Earnings Before Interest and Tax', 
                  hue = 'Ticker Symbol', size = 'Depreciation')
# Out:
# <AxesSubplot:xlabel='Earnings Before Interest and Tax', ylabel='Earnings Per Share'>

# %%
sns.scatterplot(data = complete_rows, y = 'Earnings Per Share', x = 'Earnings Before Tax', 
                  hue = 'Ticker Symbol', size = 'Income Tax')
# Out:
# <AxesSubplot:xlabel='Earnings Before Tax', ylabel='Earnings Per Share'>
